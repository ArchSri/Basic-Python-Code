# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("/data_ml.csv", parse_dates=['date'])

# %%
#Load the dataset 'data_ml.csv' to python. (Tips: use parse date parameters for date column
data
# Out:
#         stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 0             13 2006-12-31          0.25         0.33         0.27
# 1             13 2007-01-31          0.25         0.32         0.28
# 2             13 2007-02-28          0.26         0.30         0.30
# 3             17 2015-03-31          0.73         0.64         0.70
# 4             17 2015-04-30          0.72         0.62         0.66
# ...          ...        ...           ...          ...          ...
# 283375      1205 2004-05-31          0.97         0.97         0.98
# 283376      1205 2004-07-31          0.97         0.96         0.98
# 283377      1205 2004-08-31          0.97         0.96         0.97
# 283378      1205 2004-09-30          0.97         0.96         0.97
# 283379       292 2000-04-30          0.41         0.63         0.52
#
#         Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  \
# 0                 0.22    0.33  0.01         0.13         0.84  ...
# 1                 0.22    0.40  0.01         0.13         0.84  ...
# 2                 0.22    0.15  0.01         0.13         0.84  ...
# 3                 0.40    0.47  0.01         0.70         0.74  ...
# 4                 0.40    0.46  0.01         0.70         0.74  ...
# ...                ...     ...   ...          ...          ...  ...
# 283375            0.19    0.74  1.00         0.54         0.90  ...
# 283376            0.19    0.75  1.00         0.53         0.90  ...
# 283377            0.19    0.75  1.00         0.53         0.90  ...
# 283378            0.18    0.93  1.00         0.52         0.90  ...
# 283379            0.60    0.86  0.50         0.37         0.37  ...
#
#         Total_Capital  Total_Debt  Total_Debt_Capital  \
# 0                0.02        0.27                1.00
# 1                0.02        0.27                1.00
# 2                0.02        0.27                1.00
# 3                0.40        0.75                1.00
# 4                0.40        0.75                1.00
# ...               ...         ...                 ...
# 283375           0.99        0.99                0.57
# 283376           0.99        0.99                0.58
# 283377           0.99        0.99                0.58
# 283378           0.99        0.99                0.57
# 283379           0.06        0.18                0.28
#
#         Total_Liabilities_Total_Assets  Vol1Y_Usd  Vol3Y_Usd  R1M_Usd  \
# 0                                 0.92       0.84       0.88    0.089
# 1                                 0.92       0.84       0.88    0.039
# 2                                 0.92       0.87       0.88   -0.012
# 3                                 1.00       1.00       0.99    0.174
# 4                                 1.00       1.00       0.99   -0.106
# ...                                ...        ...        ...      ...
# 283375                            0.59       0.34       0.63   -0.029
# 283376                            0.60       0.29       0.64    0.028
# 283377                            0.60       0.27       0.64    0.011
# 283378                            0.60       0.26       0.66    0.045
# 283379                            0.18       0.97       0.96   -0.356
#
#         R3M_Usd  R6M_Usd  R12M_Usd
# 0         0.104    0.344    -0.041
# 1         0.091   -0.011    -0.253
# 2         0.101    0.118    -0.366
# 3        -0.144   -0.518    -0.376
# 4        -0.576   -0.535    -0.113
# ...         ...      ...       ...
# 283375   -0.027    0.038     0.112
# 283376    0.077    0.175     0.122
# 283377    0.076    0.152     0.091
# 283378    0.178    0.196     0.040
# 283379   -0.195   -0.148    -0.544
#
# [283380 rows x 99 columns]

# %%
#Print all the column names of the data 'data_ml.csv
list(data.columns)
# Out:
# ['stock_id',
#  'date',
#  'Advt_12M_Usd',
#  'Advt_3M_Usd',
#  'Advt_6M_Usd',
#  'Asset_Turnover',
#  'Bb_Yld',
#  'Bv',
#  'Capex_Ps_Cf',
#  'Capex_Sales',
#  'Cash_Div_Cf',
#  'Cash_Per_Share',
#  'Cf_Sales',
#  'Debtequity',
#  'Div_Yld',
#  'Dps',
#  'Ebit_Bv',
#  'Ebit_Noa',
#  'Ebit_Oa',
#  'Ebit_Ta',
#  'Ebitda_Margin',
#  'Eps',
#  'Eps_Basic',
#  'Eps_Basic_Gr',
#  'Eps_Contin_Oper',
#  'Eps_Dil',
#  'Ev',
#  'Ev_Ebitda',
#  'Fa_Ci',
#  'Fcf',
#  'Fcf_Bv',
#  'Fcf_Ce',
#  'Fcf_Margin',
#  'Fcf_Noa',
#  'Fcf_Oa',
#  'Fcf_Ta',
#  'Fcf_Tbv',
#  'Fcf_Toa',
#  'Fcf_Yld',
#  'Free_Ps_Cf',
#  'Int_Rev',
#  'Interest_Expense',
#  'Mkt_Cap_12M_Usd',
#  'Mkt_Cap_3M_Usd',
#  'Mkt_Cap_6M_Usd',
#  'Mom_11M_Usd',
#  'Mom_5M_Usd',
#  'Mom_Sharp_11M_Usd',
#  'Mom_Sharp_5M_Usd',
#  'Nd_Ebitda',
#  'Net_Debt',
#  'Net_Debt_Cf',
#  'Net_Margin',
#  'Netdebtyield',
#  'Ni',
#  'Ni_Avail_Margin',
#  'Ni_Oa',
#  'Ni_Toa',
#  'Noa',
#  'Oa',
#  'Ocf',
#  'Ocf_Bv',
#  'Ocf_Ce',
#  'Ocf_Margin',
#  'Ocf_Noa',
#  'Ocf_Oa',
#  'Ocf_Ta',
#  'Ocf_Tbv',
#  'Ocf_Toa',
#  'Op_Margin',
#  'Op_Prt_Margin',
#  'Oper_Ps_Net_Cf',
#  'Pb',
#  'Pe',
#  'Ptx_Mgn',
#  'Recurring_Earning_Total_Assets',
#  'Return_On_Capital',
#  'Rev',
#  'Roa',
#  'Roc',
#  'Roce',
#  'Roe',
#  'Sales_Ps',
#  'Share_Turn_12M',
#  'Share_Turn_3M',
#  'Share_Turn_6M',
#  'Ta',
#  'Tev_Less_Mktcap',
#  'Tot_Debt_Rev',
#  'Total_Capital',
#  'Total_Debt',
#  'Total_Debt_Capital',
#  'Total_Liabilities_Total_Assets',
#  'Vol1Y_Usd',
#  'Vol3Y_Usd',
#  'R1M_Usd',
#  'R3M_Usd',
#  'R6M_Usd',
#  'R12M_Usd']

# %%
#Print the top five rows of the data
top_5 = data.head(5)
top_5
# Out:
#    stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 0        13 2006-12-31          0.25         0.33         0.27
# 1        13 2007-01-31          0.25         0.32         0.28
# 2        13 2007-02-28          0.26         0.30         0.30
# 3        17 2015-03-31          0.73         0.64         0.70
# 4        17 2015-04-30          0.72         0.62         0.66
#
#    Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  Total_Capital  \
# 0            0.22    0.33  0.01         0.13         0.84  ...           0.02
# 1            0.22    0.40  0.01         0.13         0.84  ...           0.02
# 2            0.22    0.15  0.01         0.13         0.84  ...           0.02
# 3            0.40    0.47  0.01         0.70         0.74  ...           0.40
# 4            0.40    0.46  0.01         0.70         0.74  ...           0.40
#
#    Total_Debt  Total_Debt_Capital  Total_Liabilities_Total_Assets  Vol1Y_Usd  \
# 0        0.27                 1.0                            0.92       0.84
# 1        0.27                 1.0                            0.92       0.84
# 2        0.27                 1.0                            0.92       0.87
# 3        0.75                 1.0                            1.00       1.00
# 4        0.75                 1.0                            1.00       1.00
#
#    Vol3Y_Usd  R1M_Usd  R3M_Usd  R6M_Usd  R12M_Usd
# 0       0.88    0.089    0.104    0.344    -0.041
# 1       0.88    0.039    0.091   -0.011    -0.253
# 2       0.88   -0.012    0.101    0.118    -0.366
# 3       0.99    0.174   -0.144   -0.518    -0.376
# 4       0.99   -0.106   -0.576   -0.535    -0.113
#
# [5 rows x 99 columns]

# %%
#Print the descriptive statistics of the variables ‘Asset_Turnover', 'Interest_Expense', 'Eps', 'Net_Margin', 'Roa', 'Roe', 'Ta','Total_Debt', and 'R1M_Usd',
data[['Asset_Turnover', 'Interest_Expense', 'Eps', 'Net_Margin', 'Roa', 'Roe', 'Ta','Total_Debt', 'R1M_Usd']].describe()
# Out:
#        Asset_Turnover  Interest_Expense            Eps     Net_Margin  \
# count   262354.000000     262354.000000  262354.000000  262354.000000
# mean         0.511619          0.466534       0.486286       0.495940
# std          0.288071          0.258832       0.282042       0.288573
# min          0.010000          0.010000       0.010000       0.010000
# 25%          0.260000          0.250000       0.240000       0.250000
# 50%          0.510000          0.500000       0.480000       0.490000
# 75%          0.760000          0.670000       0.720000       0.740000
# max          1.000000          1.000000       1.000000       1.000000
#
#                  Roa            Roe             Ta     Total_Debt  \
# count  262353.000000  262353.000000  262353.000000  262353.000000
# mean        0.502563       0.492217       0.465142       0.468641
# std         0.287116       0.282681       0.268487       0.271209
# min         0.010000       0.010000       0.010000       0.010000
# 25%         0.260000       0.250000       0.230000       0.230000
# 50%         0.500000       0.500000       0.460000       0.470000
# 75%         0.750000       0.730000       0.690000       0.700000
# max         1.000000       1.000000       1.000000       1.000000
#
#              R1M_Usd
# count  262353.000000
# mean        0.013113
# std         0.180346
# min        -0.922000
# 25%        -0.044000
# 50%         0.011000
# 75%         0.065000
# max        30.176000

# %%
#Graphically show the relationship between the variables ‘Ta', and 'R1M_Usd'; and 'Total_Capital' and 'Total_Debt'. Use proper axes and figure titles. (tips use two separate Scatterplot)
data.plot.scatter(x= 'Total_Capital', y= 'Total_Debt')
plt.show()

# %%
data.plot.scatter(x= 'Ta', y='R1M_Usd')
plt.show()

# %%
#Sort the data by dates. 
databydate = pd.DataFrame(data)
databydate
# Out:
#         stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 0             13 2006-12-31          0.25         0.33         0.27
# 1             13 2007-01-31          0.25         0.32         0.28
# 2             13 2007-02-28          0.26         0.30         0.30
# 3             17 2015-03-31          0.73         0.64         0.70
# 4             17 2015-04-30          0.72         0.62         0.66
# ...          ...        ...           ...          ...          ...
# 283375      1205 2004-05-31          0.97         0.97         0.98
# 283376      1205 2004-07-31          0.97         0.96         0.98
# 283377      1205 2004-08-31          0.97         0.96         0.97
# 283378      1205 2004-09-30          0.97         0.96         0.97
# 283379       292 2000-04-30          0.41         0.63         0.52
#
#         Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  \
# 0                 0.22    0.33  0.01         0.13         0.84  ...
# 1                 0.22    0.40  0.01         0.13         0.84  ...
# 2                 0.22    0.15  0.01         0.13         0.84  ...
# 3                 0.40    0.47  0.01         0.70         0.74  ...
# 4                 0.40    0.46  0.01         0.70         0.74  ...
# ...                ...     ...   ...          ...          ...  ...
# 283375            0.19    0.74  1.00         0.54         0.90  ...
# 283376            0.19    0.75  1.00         0.53         0.90  ...
# 283377            0.19    0.75  1.00         0.53         0.90  ...
# 283378            0.18    0.93  1.00         0.52         0.90  ...
# 283379            0.60    0.86  0.50         0.37         0.37  ...
#
#         Total_Capital  Total_Debt  Total_Debt_Capital  \
# 0                0.02        0.27                1.00
# 1                0.02        0.27                1.00
# 2                0.02        0.27                1.00
# 3                0.40        0.75                1.00
# 4                0.40        0.75                1.00
# ...               ...         ...                 ...
# 283375           0.99        0.99                0.57
# 283376           0.99        0.99                0.58
# 283377           0.99        0.99                0.58
# 283378           0.99        0.99                0.57
# 283379           0.06        0.18                0.28
#
#         Total_Liabilities_Total_Assets  Vol1Y_Usd  Vol3Y_Usd  R1M_Usd  \
# 0                                 0.92       0.84       0.88    0.089
# 1                                 0.92       0.84       0.88    0.039
# 2                                 0.92       0.87       0.88   -0.012
# 3                                 1.00       1.00       0.99    0.174
# 4                                 1.00       1.00       0.99   -0.106
# ...                                ...        ...        ...      ...
# 283375                            0.59       0.34       0.63   -0.029
# 283376                            0.60       0.29       0.64    0.028
# 283377                            0.60       0.27       0.64    0.011
# 283378                            0.60       0.26       0.66    0.045
# 283379                            0.18       0.97       0.96   -0.356
#
#         R3M_Usd  R6M_Usd  R12M_Usd
# 0         0.104    0.344    -0.041
# 1         0.091   -0.011    -0.253
# 2         0.101    0.118    -0.366
# 3        -0.144   -0.518    -0.376
# 4        -0.576   -0.535    -0.113
# ...         ...      ...       ...
# 283375   -0.027    0.038     0.112
# 283376    0.077    0.175     0.122
# 283377    0.076    0.152     0.091
# 283378    0.178    0.196     0.040
# 283379   -0.195   -0.148    -0.544
#
# [283380 rows x 99 columns]

# %%
#Divide the data into two parts and name them 'train_data' and 'test data'. The 'train_data' should consist of all the dates before 01/01/2015. The test_data should consist of all the dates from 01/01/2015 to 03/31/2019.
train_data = data.loc[data['date'] <= "2015-01-01 00:00:00"]
test_data = data.loc[data['date'] > "2015-01-01 23:59:59"]

test_data
# Out:
#         stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 3             17 2015-03-31          0.73         0.64         0.70
# 4             17 2015-04-30          0.72         0.62         0.66
# 5             17 2015-05-31          0.71         0.63         0.64
# 6             17 2015-06-30          0.70         0.62         0.63
# 7             17 2015-07-31          0.68         0.56         0.60
# ...          ...        ...           ...          ...          ...
# 262277       436 2018-10-31          0.98         0.98         0.98
# 262278       436 2018-11-30          0.98         0.98         0.98
# 262309       462 2015-12-31          0.94         0.95         0.94
# 262310       462 2016-01-31          0.94         0.95         0.94
# 262311       462 2016-02-29          0.94         0.95         0.95
#
#         Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  \
# 3                 0.40    0.47  0.01         0.70         0.74  ...
# 4                 0.40    0.46  0.01         0.70         0.74  ...
# 5                 0.40    0.47  0.01         0.70         0.74  ...
# 6                 0.38    0.43  0.01         0.53         0.66  ...
# 7                 0.38    0.45  0.01         0.53         0.66  ...
# ...                ...     ...   ...          ...          ...  ...
# 262277            0.50    0.80  0.93         0.87         0.66  ...
# 262278            0.50    0.79  0.93         0.87         0.66  ...
# 262309            0.20    0.39  0.93         0.98         0.97  ...
# 262310            0.20    0.40  0.93         0.98         0.97  ...
# 262311            0.20    0.40  0.93         0.98         0.97  ...
#
#         Total_Capital  Total_Debt  Total_Debt_Capital  \
# 3                0.40        0.75                1.00
# 4                0.40        0.75                1.00
# 5                0.40        0.75                1.00
# 6                0.25        0.74                1.00
# 7                0.25        0.74                1.00
# ...               ...         ...                 ...
# 262277           0.96        0.98                0.88
# 262278           0.96        0.98                0.88
# 262309           0.94        0.94                0.72
# 262310           0.94        0.94                0.72
# 262311           0.94        0.94                0.72
#
#         Total_Liabilities_Total_Assets  Vol1Y_Usd  Vol3Y_Usd  R1M_Usd  \
# 3                                 1.00       1.00       0.99    0.174
# 4                                 1.00       1.00       0.99   -0.106
# 5                                 1.00       1.00       0.99   -0.185
# 6                                 1.00       1.00       0.99   -0.418
# 7                                 1.00       1.00       0.99    0.575
# ...                                ...        ...        ...      ...
# 262277                            0.80       0.20       0.14    0.091
# 262278                            0.80       0.27       0.15   -0.085
# 262309                            0.59       0.85       0.70   -0.195
# 262310                            0.59       0.90       0.80   -0.029
# 262311                            0.59       0.93       0.84    0.229
#
#         R3M_Usd  R6M_Usd  R12M_Usd
# 3        -0.144   -0.518    -0.376
# 4        -0.576   -0.535    -0.113
# 5        -0.252   -0.578    -0.194
# 6        -0.436   -0.635     0.309
# 7         0.095   -0.361     2.139
# ...         ...      ...       ...
# 262277    0.179    0.000     0.000
# 262278    0.145    0.000     0.000
# 262309   -0.040    0.103     0.441
# 262310    0.351    0.398     0.785
# 262311    0.368    0.412     0.707
#
# [53626 rows x 99 columns]

# %%
train_data
# Out:
#         stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 0             13 2006-12-31          0.25         0.33         0.27
# 1             13 2007-01-31          0.25         0.32         0.28
# 2             13 2007-02-28          0.26         0.30         0.30
# 30            29 2002-09-30          0.43         0.18         0.28
# 31            29 2002-10-31          0.41         0.18         0.23
# ...          ...        ...           ...          ...          ...
# 262349       474 2013-01-31          0.91         0.90         0.91
# 262350       474 2013-02-28          0.91         0.91         0.92
# 262351       474 2013-03-31          0.91         0.92         0.92
# 262352       474 2013-04-30          0.92         0.92         0.92
# 262353       474 2013-05-31          0.92         0.93         0.92
#
#         Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  \
# 0                 0.22    0.33  0.01         0.13         0.84  ...
# 1                 0.22    0.40  0.01         0.13         0.84  ...
# 2                 0.22    0.15  0.01         0.13         0.84  ...
# 30                0.29    0.78  0.01         0.30         0.86  ...
# 31                0.29    0.58  0.01         0.30         0.86  ...
# ...                ...     ...   ...          ...          ...  ...
# 262349            0.83    0.80  0.93         0.97         0.79  ...
# 262350            0.83    0.79  0.93         0.97         0.79  ...
# 262351            0.83    0.24  0.93         0.98         0.78  ...
# 262352            0.83    0.25  0.93         0.98         0.78  ...
# 262353            0.83    0.28  0.93         0.98         0.78  ...
#
#         Total_Capital  Total_Debt  Total_Debt_Capital  \
# 0                0.02        0.27                1.00
# 1                0.02        0.27                1.00
# 2                0.02        0.27                1.00
# 30               0.16        0.49                1.00
# 31               0.16        0.49                1.00
# ...               ...         ...                 ...
# 262349           0.90        0.74                0.21
# 262350           0.90        0.74                0.21
# 262351           0.90        0.72                0.20
# 262352           0.90        0.72                0.20
# 262353            NaN         NaN                 NaN
#
#         Total_Liabilities_Total_Assets  Vol1Y_Usd  Vol3Y_Usd  R1M_Usd  \
# 0                                 0.92       0.84       0.88    0.089
# 1                                 0.92       0.84       0.88    0.039
# 2                                 0.92       0.87       0.88   -0.012
# 30                                1.00       0.99       0.97    0.169
# 31                                1.00       0.99       0.97    1.239
# ...                                ...        ...        ...      ...
# 262349                            0.39       0.27       0.30    0.023
# 262350                            0.39       0.28       0.30   -0.067
# 262351                            0.36       0.33       0.33   -0.043
# 262352                            0.36       0.31       0.32    0.025
# 262353                             NaN        NaN        NaN      NaN
#
#         R3M_Usd  R6M_Usd  R12M_Usd
# 0         0.104    0.344    -0.041
# 1         0.091   -0.011    -0.253
# 2         0.101    0.118    -0.366
# 30        1.084    0.699     4.169
# 31        0.371    1.630     7.144
# ...         ...      ...       ...
# 262349   -0.071    0.048     0.321
# 262350   -0.085    0.021     0.271
# 262351    0.005    0.165     0.357
# 262352    0.129    0.398     0.457
# 262353      NaN      NaN       NaN
#
# [208728 rows x 99 columns]

# %%
#Print the descriptive statistics of the variables ‘Asset_Turnover', 'Interest_Expense', 'Eps', 'Net_Margin', 'Roa', 'Roe', 'Ta','Total_Debt', and 'R1M_Usd',
test_data[['Asset_Turnover', 'Interest_Expense', 'Eps', 'Net_Margin', 'Roa', 'Roe', 'Ta','Total_Debt', 'R1M_Usd']].describe()
# Out:
#        Asset_Turnover  Interest_Expense           Eps    Net_Margin  \
# count    53626.000000      53626.000000  53626.000000  53626.000000
# mean         0.516381          0.458214      0.489197      0.496115
# std          0.288734          0.265115      0.282862      0.287491
# min          0.010000          0.010000      0.010000      0.010000
# 25%          0.260000          0.230000      0.250000      0.250000
# 50%          0.530000          0.460000      0.480000      0.490000
# 75%          0.760000          0.670000      0.730000      0.740000
# max          1.000000          1.000000      1.000000      1.000000
#
#                 Roa           Roe            Ta    Total_Debt       R1M_Usd
# count  53626.000000  53626.000000  53626.000000  53626.000000  53626.000000
# mean       0.505997      0.493605      0.463551      0.464635      0.010509
# std        0.289630      0.284321      0.268101      0.270524      0.224407
# min        0.010000      0.010000      0.010000      0.010000     -0.826000
# 25%        0.260000      0.250000      0.230000      0.230000     -0.041000
# 50%        0.510000      0.500000      0.460000      0.460000      0.007000
# 75%        0.760000      0.730000      0.690000      0.690000      0.056000
# max        1.000000      1.000000      0.990000      1.000000     30.176000

# %%
train_data[['Asset_Turnover', 'Interest_Expense', 'Eps', 'Net_Margin', 'Roa', 'Roe', 'Ta','Total_Debt', 'R1M_Usd']].describe()
# Out:
#        Asset_Turnover  Interest_Expense            Eps     Net_Margin  \
# count   208728.000000     208728.000000  208728.000000  208728.000000
# mean         0.510395          0.468671       0.485538       0.495896
# std          0.287888          0.257151       0.281827       0.288850
# min          0.010000          0.010000       0.010000       0.010000
# 25%          0.260000          0.260000       0.240000       0.240000
# 50%          0.510000          0.500000       0.480000       0.490000
# 75%          0.760000          0.670000       0.720000       0.740000
# max          1.000000          1.000000       1.000000       1.000000
#
#                 Roa            Roe             Ta     Total_Debt  \
# count  208727.00000  208727.000000  208727.000000  208727.000000
# mean        0.50168       0.491861       0.465550       0.469670
# std         0.28646       0.282257       0.268585       0.271376
# min         0.01000       0.010000       0.010000       0.010000
# 25%         0.26000       0.250000       0.230000       0.240000
# 50%         0.50000       0.500000       0.460000       0.470000
# 75%         0.75000       0.730000       0.690000       0.700000
# max         1.00000       1.000000       1.000000       1.000000
#
#              R1M_Usd
# count  208727.000000
# mean        0.013782
# std         0.167155
# min        -0.922000
# 25%        -0.045000
# 50%         0.012000
# 75%         0.068000
# max        27.233000
